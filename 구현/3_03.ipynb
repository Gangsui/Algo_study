# %%
def coprmime(a,b):
    for i in range(2,min(a,b)+1):
        if a%i ==0 and b%i==0:
            return False
    return True

assert not coprmime(4,9),'ㅁ'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In [12], line 7
#       4             return False
#       5     return True
# ----> 7 assert not coprmime(4,9),'ㅁ'
#
# AssertionError: ㅁ

# %%
from urllib.parse import parse_qs

my_values=parse_qs('빨강=5&파랑=0&초록=',keep_blank_values= True)

# print(repr(my_values))
red=my_values.get('초록',[''])[0] or 0

print(repr(my_values))
# Out:
# {'빨강': ['5'], '파랑': ['0'], '초록': ['']}

# %%
def make_lemonade(count):
    return print(count)
fresh_fruit={'사과':10,
             '바나나':8,
             '레몬':5,
             }
print(repr(fresh_fruit.get('사과')))
if (count:=fresh_fruit.get('사과',0))>=11:
    make_lemonade(count)
# Out:
# 10

# %%
a=13
if [3,13] in a:
    print('a')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [46], line 2
#       1 a=13
# ----> 2 if [3,13] in a:
#       3     print('a')
#
# TypeError: argument of type 'int' is not iterable

# %%
N=int(input())
count=0
for hour in range(0,N+1):
    for min in range(60):
        for secound in range(60):
            if secound in [3,13,23,33,43,53] or hour in [3,13] or min in [3,13,23,33,43,53]:
                print(hour,min,secound)
                count+=1
print(count)
# Out:
# 0 0 3
# 0 0 13
# 0 0 23
# 0 0 33
# 0 0 43
# 0 0 53
# 0 1 3
# 0 1 13
# 0 1 23
# 0 1 33
# 0 1 43
# 0 1 53
# 0 2 3
# 0 2 13
# 0 2 23
# 0 2 33
# 0 2 43
# 0 2 53
# 0 3 0
# 0 3 1
# 0 3 2
# 0 3 3
# 0 3 4
# 0 3 5
# 0 3 6
# 0 3 7
# 0 3 8
# 0 3 9
# 0 3 10
# 0 3 11
# 0 3 12
# 0 3 13
# 0 3 14
# 0 3 15
# 0 3 16
# 0 3 17
# 0 3 18
# 0 3 19
# 0 3 20
# 0 3 21
# 0 3 22
# 0 3 23
# 0 3 24
# 0 3 25
# 0 3 26
# 0 3 27
# 0 3 28
# 0 3 29
# 0 3 30
# 0 3 31
# 0 3 32
# 0 3 33
# 0 3 34
# 0 3 35
# 0 3 36
# 0 3 37
# 0 3 38
# 0 3 39
# 0 3 40
# 0 3 41
# 0 3 42
# 0 3 43
# 0 3 44
# 0 3 45
# 0 3 46
# 0 3 47
# 0 3 48
# 0 3 49
# 0 3 50
# 0 3 51
# 0 3 52
# 0 3 53
# 0 3 54
# 0 3 55
# 0 3 56
# 0 3 57
# 0 3 58
# 0 3 59
# 0 4 3
# 0 4 13
# 0 4 23
# 0 4 33
# 0 4 43
# 0 4 53
# 0 5 3
# 0 5 13
# 0 5 23
# 0 5 33
# 0 5 43
# 0 5 53
# 0 6 3
# 0 6 13
# 0 6 23
# 0 6 33
# 0 6 43
# 0 6 53
# 0 7 3
# 0 7 13
# 0 7 23
# 0 7 33
# 0 7 43
# 0 7 53
# 0 8 3
# 0 8 13
# 0 8 23
# 0 8 33
# 0 8 43
# 0 8 53
# 0 9 3
# 0 9 13
# 0 9 23
# 0 9 33
# 0 9 43
# ...

# %%
N=int(input())
count=0
for hour in range(0,N+1):
    for min in range(60):
        for secound in range(60):
            if '3' in str(hour) + str(min)+ str(secound):
                print(hour,min,secound)
                count+=1
print(count)
# Out:
# 0 0 3
# 0 0 13
# 0 0 23
# 0 0 30
# 0 0 31
# 0 0 32
# 0 0 33
# 0 0 34
# 0 0 35
# 0 0 36
# 0 0 37
# 0 0 38
# 0 0 39
# 0 0 43
# 0 0 53
# 0 1 3
# 0 1 13
# 0 1 23
# 0 1 30
# 0 1 31
# 0 1 32
# 0 1 33
# 0 1 34
# 0 1 35
# 0 1 36
# 0 1 37
# 0 1 38
# 0 1 39
# 0 1 43
# 0 1 53
# 0 2 3
# 0 2 13
# 0 2 23
# 0 2 30
# 0 2 31
# 0 2 32
# 0 2 33
# 0 2 34
# 0 2 35
# 0 2 36
# 0 2 37
# 0 2 38
# 0 2 39
# 0 2 43
# 0 2 53
# 0 3 0
# 0 3 1
# 0 3 2
# 0 3 3
# 0 3 4
# 0 3 5
# 0 3 6
# 0 3 7
# 0 3 8
# 0 3 9
# 0 3 10
# 0 3 11
# 0 3 12
# 0 3 13
# 0 3 14
# 0 3 15
# 0 3 16
# 0 3 17
# 0 3 18
# 0 3 19
# 0 3 20
# 0 3 21
# 0 3 22
# 0 3 23
# 0 3 24
# 0 3 25
# 0 3 26
# 0 3 27
# 0 3 28
# 0 3 29
# 0 3 30
# 0 3 31
# 0 3 32
# 0 3 33
# 0 3 34
# 0 3 35
# 0 3 36
# 0 3 37
# 0 3 38
# 0 3 39
# 0 3 40
# 0 3 41
# 0 3 42
# 0 3 43
# 0 3 44
# 0 3 45
# 0 3 46
# 0 3 47
# 0 3 48
# 0 3 49
# 0 3 50
# 0 3 51
# 0 3 52
# 0 3 53
# 0 3 54
# 0 3 55
# 0 3 56
# 0 3 57
# 0 3 58
# 0 3 59
# 0 4 3
# 0 4 13
# 0 4 23
# 0 4 30
# 0 4 31
# 0 4 32
# 0 4 33
# ...

# %%
print('aa')
